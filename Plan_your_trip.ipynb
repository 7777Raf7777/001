# %% [markdown]
# ![Kayak](https://seekvectorlogo.com/wp-content/uploads/2018/01/kayak-vector-logo.png)
#
# # Plan your trip with Kayak
#
# ## Company's description 📇
#
# <a href="https://www.kayak.com" target="_blank">Kayak</a> is a travel search engine that helps user plan their next trip at the best price.
#
# The company was founded in 2004 by Steve Hafner & Paul M. English. After a few rounds of fundraising, Kayak was acquired by <a href="https://www.bookingholdings.com/" target="_blank">Booking Holdings</a> which now holds:
#
# * <a href="https://booking.com/" target="_blank">Booking.com</a>
# * <a href="https://kayak.com/" target="_blank">Kayak</a>
# * <a href="https://www.priceline.com/" target="_blank">Priceline</a>
# * <a href="https://www.agoda.com/" target="_blank">Agoda</a>
# * <a href="https://Rentalcars.com/" target="_blank">RentalCars</a>
# * <a href="https://www.opentable.com/" target="_blank">OpenTable</a>
#
# With over \$300 million revenue a year, Kayak operates in almost all countries and all languages to help their users book travels accros the globe.

# %% [markdown]
# ## Project 🚧
#
# The marketing team needs help on a new project. After doing some user research, the team discovered that **70% of their users who are planning a trip would like to have more information about the destination they are going to**.
#
# In addition, user research shows that **people tend to be defiant about the information they are reading if they don't know the brand** which produced the content.
#
# Therefore, Kayak Marketing Team would like to create an application that will recommend where people should plan their next holidays. The application should be based on real data about:
#
# * Weather
# * Hotels in the area
#
# The application should then be able to recommend the best destinations and hotels based on the above variables at any given time.

# %% [markdown]
# ## Goals 🎯
#
# As the project has just started, your team doesn't have any data that can be used to create this application. Therefore, your job will be to:
#
# * Scrape data from destinations
# * Get weather data from each destination
# * Get hotels' info about each destination
# * Store all the information above in a data lake
# * Extract, transform and load cleaned data from your datalake to a data warehouse

# %%
import pandas as pd
import plotly.express as px
import json
import boto3
import ast
import folium
import requests
from io import BytesIO
from branca.element import Figure
from sqlalchemy import create_engine, text

# %%
cities = [
    "Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris",
    "Amiens", "Lille", "Strasbourg", "Chateau du Haut Koenigsbourg", "Colmar",
    "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon",
    "Gorges du Verdon", "Bormes les Mimosas", "Cassis", "Marseille",
    "Aix en Provence", "Avignon", "Uzes", "Nimes", "Aigues Mortes",
    "Saintes Maries de la mer", "Collioure", "Carcassonne", "Ariege",
    "Toulouse", "Montauban", "Biarritz", "Bayonne", "La Rochelle"
]

# %%
def get_coordinates(city):
    # Replace spaces with '+' characters
    city = city.replace(' ', '+')
    
    # Set the query URL with the specified city
    url = f"https://nominatim.openstreetmap.org/search?q={city}&format=json"
    
    headers = {
        'User-Agent': 'my-app/0.0.1'  # Replace with your app name and version
    }

    try:
        # Executes GET request to Nominatim API with headers
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise HTTPError for bad responses

        # Get JSON data from response
        data = response.json()

        if data:
            # Extract latitude and longitude from the first result
            lat = data[0]['lat']
            lon = data[0]['lon']
            return lat, lon
        else:
            print(f"No coordinates found for {city}")
            return None, None
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching coordinates for {city}: {e}")
        return None, None

# Example usage:
city = "New York"
latitude, longitude = get_coordinates(city)
if latitude and longitude:
    print(f"The coordinates of {city} are: Latitude {latitude}, Longitude {longitude}")
else:
    print(f"Failed to retrieve coordinates for {city}")
# Out:
# The coordinates of New York are: Latitude 40.7127281, Longitude -74.0060152

# %%
# Creating a DataFrame to store GPS coordinate information
coordinates_df = pd.DataFrame(columns=['City', 'Latitude', 'Longitude'])

# Loop through the list of cities to get coordinates for each city
for city in cities:
    lat, lon = get_coordinates(city)
    new_row = pd.DataFrame({
        'City': [city],
        'Latitude': [lat],
        'Longitude': [lon]
    })
    coordinates_df = pd.concat([coordinates_df, new_row], ignore_index=True)

coordinates_df
# Out:
#                             City            Latitude           Longitude
# 0              Mont Saint Michel          48.6359541  -1.511459954959514
# 1                        St Malo           49.314695         -96.9538228
# 2                         Bayeux          49.2764624          -0.7024738
# 3                       Le Havre          49.4938975           0.1079732
# 4                          Rouen          49.4404591           1.0939658
# 5                          Paris          48.8534951           2.3483915
# 6                         Amiens          49.8941708           2.2956951
# 7                          Lille          50.6365654           3.0635282
# 8                     Strasbourg           48.584614           7.7507127
# 9   Chateau du Haut Koenigsbourg  48.249410749999996   7.344320233724503
# 10                        Colmar          48.0777517           7.3579641
# 11                     Eguisheim          48.0447968           7.3079618
# 12                      Besancon          47.2380222           6.0243622
# 13                         Dijon          47.3215806           5.0414701
# 14                        Annecy          45.8992348           6.1288847
# 15                      Grenoble          45.1875602           5.7357819
# 16                          Lyon          45.7578137           4.8320114
# 17              Gorges du Verdon          43.7496562           6.3285616
# 18            Bormes les Mimosas          43.1506968           6.3419285
# 19                        Cassis          43.2140359           5.5396318
# 20                     Marseille          43.2961743           5.3699525
# 21               Aix en Provence          43.5298424           5.4474738
# 22                       Avignon          43.9492493           4.8059012
# 23                          Uzes          44.0121279           4.4196718
# 24                         Nimes          43.8374249           4.3600687
# 25                 Aigues Mortes          43.5661521             4.19154
# 26      Saintes Maries de la mer          43.4515922           4.4277202
# 27                     Collioure            42.52505           3.0831554
# 28                   Carcassonne          43.2130358           2.3491069
# 29                        Ariege          42.9455368  1.4065544156065486
# 30                      Toulouse          43.6044622           1.4442469
# 31                     Montauban          44.0175835           1.3549991
# 32                      Biarritz          43.4832523          -1.5592776
# 33                       Bayonne          43.4945144          -1.4736657
# 34                   La Rochelle          46.1591126          -1.1520434

# %%
# API key obtained following registration on the site
api_key = "6005eb181c0e673b5a45954c37cc6b79" # Your Open-weather API key

# Function to retrieve weather data using the OpenWeatherMap API 
def get_weather(lat, lon):
    url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        weather_data = response.json()
        return weather_data
    else:
        print(f"Failed to get weather data: Status code {response.status_code}, Response: {response.text}")
        return None
    
# Applies the function to each line of `coordinates_df` to retrieve detailed weather data
coordinates_df['Weather'] = coordinates_df.apply(lambda row: get_weather(row['Latitude'], row['Longitude']), axis=1)
coordinates_df
# Out:
#                             City            Latitude           Longitude  \
# 0              Mont Saint Michel          48.6359541  -1.511459954959514
# 1                        St Malo           49.314695         -96.9538228
# 2                         Bayeux          49.2764624          -0.7024738
# 3                       Le Havre          49.4938975           0.1079732
# 4                          Rouen          49.4404591           1.0939658
# 5                          Paris          48.8534951           2.3483915
# 6                         Amiens          49.8941708           2.2956951
# 7                          Lille          50.6365654           3.0635282
# 8                     Strasbourg           48.584614           7.7507127
# 9   Chateau du Haut Koenigsbourg  48.249410749999996   7.344320233724503
# 10                        Colmar          48.0777517           7.3579641
# 11                     Eguisheim          48.0447968           7.3079618
# 12                      Besancon          47.2380222           6.0243622
# 13                         Dijon          47.3215806           5.0414701
# 14                        Annecy          45.8992348           6.1288847
# 15                      Grenoble          45.1875602           5.7357819
# 16                          Lyon          45.7578137           4.8320114
# 17              Gorges du Verdon          43.7496562           6.3285616
# 18            Bormes les Mimosas          43.1506968           6.3419285
# 19                        Cassis          43.2140359           5.5396318
# 20                     Marseille          43.2961743           5.3699525
# 21               Aix en Provence          43.5298424           5.4474738
# 22                       Avignon          43.9492493           4.8059012
# 23                          Uzes          44.0121279           4.4196718
# 24                         Nimes          43.8374249           4.3600687
# 25                 Aigues Mortes          43.5661521             4.19154
# 26      Saintes Maries de la mer          43.4515922           4.4277202
# 27                     Collioure            42.52505           3.0831554
# 28                   Carcassonne          43.2130358           2.3491069
# 29                        Ariege          42.9455368  1.4065544156065486
# 30                      Toulouse          43.6044622           1.4442469
# 31                     Montauban          44.0175835           1.3549991
# 32                      Biarritz          43.4832523          -1.5592776
# 33                       Bayonne          43.4945144          -1.4736657
# 34                   La Rochelle          46.1591126          -1.1520434
#
#                                               Weather
# 0   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 1   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 2   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 3   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 4   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 5   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 6   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 7   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 8   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 9   {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 10  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 11  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 12  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 13  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 14  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 15  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 16  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 17  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 18  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 19  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 20  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 21  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 22  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 23  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 24  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 25  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 26  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 27  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 28  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 29  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 30  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 31  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 32  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 33  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 34  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...

# %%
# Data transformation into csv file
coordinates_df.to_csv('coordinates.csv', index=False)

# %%
def weather(weather_data):
    total_temp = 0
    total_precipitation = 0
    
    if 'list' in weather_data:
        for day in weather_data['list']:
            # Conversion de Kelvin en Celsius pour la température
            temp_celsius = day['main']['temp'] - 273.15
            total_temp += temp_celsius
            
            # Ajout des précipitations en millimètres s'il y en a
            if 'rain' in day and '3h' in day['rain']:
                total_precipitation += day['rain']['3h']
        
        # Calcul de la moyenne de la température en Celsius
        if len(weather_data['list']) > 0:
            average_temp = total_temp / len(weather_data['list'])
        else:
            average_temp = 0
    else:
        average_temp = 0
        total_precipitation = 0
    
    return average_temp, total_precipitation

# %%
coordinates_df[['AverageTemp', 'TotalPrecipitation']] = coordinates_df.apply(lambda row: weather(row['Weather']), axis=1, result_type='expand')

# %%
coordinates_df.head()
# Out:
#                 City    Latitude           Longitude  \
# 0  Mont Saint Michel  48.6359541  -1.511459954959514
# 1            St Malo   49.314695         -96.9538228
# 2             Bayeux  49.2764624          -0.7024738
# 3           Le Havre  49.4938975           0.1079732
# 4              Rouen  49.4404591           1.0939658
#
#                                              Weather  AverageTemp  \
# 0  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     18.61775
# 1  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     17.42875
# 2  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     18.03350
# 3  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     18.48325
# 4  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     19.13275
#
#    TotalPrecipitation
# 0                8.34
# 1                6.89
# 2                7.33
# 3                7.65
# 4                7.31

# %%
#!python scraping.py

# %%
# Reading the Json file recovered during scraping
booking_df = pd.read_json('hotels.json')
booking_df.head()
# Out:
#                 City                 Hotel Name  \
# 0  Mont Saint Michel                 Hôtel Vert
# 1  Mont Saint Michel      Les Terrasses Poulard
# 2  Mont Saint Michel  Mercure Mont Saint Michel
# 3  Mont Saint Michel           Le Relais Du Roy
# 4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description   Latitude  Longitude
# 0  Hotel Vert offers pastel-coloured rooms with a...  48.614700  -1.509617
# 1  Composed of 2 different buildings, Les Terrass...  48.635349  -1.510379
# 2  This Mercure is situated in parkland just 2 km...  48.614247  -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...  48.616263  -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...  48.617587  -1.510396

# %%
# Renaming columns for clarity and avoid confusion when merging data
booking_df.rename(columns={'Latitude': 'lat_hotels', 'Longitude': 'lon_hotels'}, inplace=True)
booking_df.head()
# Out:
#                 City                 Hotel Name  \
# 0  Mont Saint Michel                 Hôtel Vert
# 1  Mont Saint Michel      Les Terrasses Poulard
# 2  Mont Saint Michel  Mercure Mont Saint Michel
# 3  Mont Saint Michel           Le Relais Du Roy
# 4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description  lat_hotels  lon_hotels
# 0  Hotel Vert offers pastel-coloured rooms with a...   48.614700   -1.509617
# 1  Composed of 2 different buildings, Les Terrass...   48.635349   -1.510379
# 2  This Mercure is situated in parkland just 2 km...   48.614247   -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...   48.616263   -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...   48.617587   -1.510396

# %%
# Data Merge
df_full = pd.merge(booking_df, coordinates_df, on='City')
df_full.head()
# Out:
#                 City                 Hotel Name  \
# 0  Mont Saint Michel                 Hôtel Vert
# 1  Mont Saint Michel      Les Terrasses Poulard
# 2  Mont Saint Michel  Mercure Mont Saint Michel
# 3  Mont Saint Michel           Le Relais Du Roy
# 4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description  lat_hotels  lon_hotels  \
# 0  Hotel Vert offers pastel-coloured rooms with a...   48.614700   -1.509617
# 1  Composed of 2 different buildings, Les Terrass...   48.635349   -1.510379
# 2  This Mercure is situated in parkland just 2 km...   48.614247   -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...   48.616263   -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...   48.617587   -1.510396
#
#      Latitude           Longitude  \
# 0  48.6359541  -1.511459954959514
# 1  48.6359541  -1.511459954959514
# 2  48.6359541  -1.511459954959514
# 3  48.6359541  -1.511459954959514
# 4  48.6359541  -1.511459954959514
#
#                                              Weather  AverageTemp  \
# 0  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     18.61775
# 1  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     18.61775
# 2  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     18.61775
# 3  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     18.61775
# 4  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...     18.61775
#
#    TotalPrecipitation
# 0                8.34
# 1                8.34
# 2                8.34
# 3                8.34
# 4                8.34

# %%
# saving final data to a csv file
df_full.to_csv('df_full.csv', index=False)

# %% [markdown]
# --- Plot of the 5 best destinations in France according to temperature ---

# %%
df_temp = df_full[['City', 'AverageTemp', 'Latitude', 'Longitude', 'TotalPrecipitation']]

df_temp_sorted = df_temp.sort_values(by='AverageTemp', ascending=False)

df_temp_unique = df_temp_sorted.drop_duplicates(subset=['City'])

top_5_cities = df_temp_unique.head(5)

# Affichage du top 5 des villes avec la température la plus élevée
print("Top 5 cities with the highest temperature:")
print(top_5_cities)
# Out:
# Top 5 cities with the highest temperature:
#                 City  AverageTemp    Latitude  Longitude  TotalPrecipitation
# 550  Aix en Provence     28.48825  43.5298424  5.4474738                0.00
# 612            Nimes     27.90900  43.8374249  4.3600687                0.00
# 528          Avignon     27.49800  43.9492493  4.8059012                0.81
# 603             Uzes     26.81250  44.0121279  4.4196718                0.00
# 777      Carcassonne     26.51625  43.2130358  2.3491069                1.10

# %%
# Creates a figure to contain the map with a title
cities_fig = Figure(width=800, height=400)
cities_fig.html.add_child(folium.Element("<h3 style='text-align:center;margin-top:20px;'>Top 5 des villes avec la meilleure météo</h3>"))

# Create a map centered around France
map_france = folium.Map(location=[46.2276, 2.2137], zoom_start=6, tiles='OpenStreetMap')
cities_fig.add_child(map_france)

# Ajoute des marqueurs pour les top 5 destinations
for _, row in top_5_cities.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['City']}: Temp {row['AverageTemp']}°C, Precip {row['TotalPrecipitation']}mm",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(map_france)

# Shows the map with the title
cities_fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2c8e24b984421c3d6f236b62e26803f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 style=&#x27;text-align:center;margin-top:20px;&#x27;&gt;Top 5 des villes avec la meilleure météo&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2c8e24b984421c3d6f236b62e26803f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2c8e24b984421c3d6f236b62e26803f = L.map(
#                 &quot;map_e2c8e24b984421c3d6f236b62e26803f&quot;,
#                 {
#                     center: [46.2276, 2.2137],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a530779f19ad9aa70d87d98300e8d20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3a530779f19ad9aa70d87d98300e8d20.addTo(map_e2c8e24b984421c3d6f236b62e26803f);
#
#
#             var marker_26fd68ed0e253f79873e55319e487ccf = L.marker(
#                 [43.5298424, 5.4474738],
#                 {}
#             ).addTo(map_e2c8e24b984421c3d6f236b62e26803f);
#
#
#             var icon_580fc51609a222959791a206d465ed2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_26fd68ed0e253f79873e55319e487ccf.setIcon(icon_580fc51609a222959791a206d465ed2e);
#
#
#         var popup_67686aea78ea8593c0ca4d8f26a4e2fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea97c2409c1377eaff62baf9477268e0 = $(`&lt;div id=&quot;html_ea97c2409c1377eaff62baf9477268e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aix en Provence: Temp 28.48825000000003°C, Precip 0.0mm&lt;/div&gt;`)[0];
#                 popup_67686aea78ea8593c0ca4d8f26a4e2fb.setContent(html_ea97c2409c1377eaff62baf9477268e0);
#
#
#
#         marker_26fd68ed0e253f79873e55319e487ccf.bindPopup(popup_67686aea78ea8593c0ca4d8f26a4e2fb)
#         ;
#
#
#
#
#             var marker_363f3964f6d83a78353b79b4f57d684d = L.marker(
#                 [43.8374249, 4.3600687],
#                 {}
#             ).addTo(map_e2c8e24b984421c3d6f236b62e26803f);
#
#
#             var icon_2e9813caa0a8d50d3daab1663028649a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_363f3964f6d83a78353b79b4f57d684d.setIcon(icon_2e9813caa0a8d50d3daab1663028649a);
#
#
#         var popup_accd5ac3accdf138100d8267f948dea0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e22613ff27efd3d0e98fbcd25a7c8b8 = $(`&lt;div id=&quot;html_8e22613ff27efd3d0e98fbcd25a7c8b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nimes: Temp 27.909000000000027°C, Precip 0.0mm&lt;/div&gt;`)[0];
#                 popup_accd5ac3accdf138100d8267f948dea0.setContent(html_8e22613ff27efd3d0e98fbcd25a7c8b8);
#
#
#
#         marker_363f3964f6d83a78353b79b4f57d684d.bindPopup(popup_accd5ac3accdf138100d8267f948dea0)
#         ;
#
#
#
#
#             var marker_b4ca8ee804d746f0a730afd6c6071b08 = L.marker(
#                 [43.9492493, 4.8059012],
#                 {}
#             ).addTo(map_e2c8e24b984421c3d6f236b62e26803f);
#
#
#             var icon_c829a8cf6a6e0fb3901a276c8895eac2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b4ca8ee804d746f0a730afd6c6071b08.setIcon(icon_c829a8cf6a6e0fb3901a276c8895eac2);
#
#
#         var popup_516a33b53e992e016f42d52fbd97505f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_203b716c0c5263255da19cc81bd98283 = $(`&lt;div id=&quot;html_203b716c0c5263255da19cc81bd98283&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avignon: Temp 27.498000000000026°C, Precip 0.81mm&lt;/div&gt;`)[0];
#                 popup_516a33b53e992e016f42d52fbd97505f.setContent(html_203b716c0c5263255da19cc81bd98283);
#
#
#
#         marker_b4ca8ee804d746f0a730afd6c6071b08.bindPopup(popup_516a33b53e992e016f42d52fbd97505f)
#         ;
#
#
#
#
#             var marker_85e1868e0097682e568c7785a5fd1490 = L.marker(
#                 [44.0121279, 4.4196718],
#                 {}
#             ).addTo(map_e2c8e24b984421c3d6f236b62e26803f);
#
#
#             var icon_7b87e021272270db0988b457fa7edb2c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconC

# %% [markdown]
# --- Top 20 des hotels pour chacune des villes ---

# %%
# Replaces NaNs in 'Score' column with 0 and eliminates rows with NaN coordinates
df_full['Score'].fillna(0, inplace=True)
df_full.dropna(subset=['lat_hotels', 'lon_hotels'], inplace=True)

# Filter hotels to only keep those in the top 5 cities
top_cities = top_5_cities['City'].tolist()
filtered_hotels = df_full[df_full['City'].isin(top_cities)]

# Selects the top 20 hotels for each city based on score
top_hotels = filtered_hotels.groupby('City').apply(lambda x: x.nlargest(20, 'Score')).reset_index(drop=True)
# Out:
# C:\Users\Rafik\AppData\Local\Temp\ipykernel_27632\3763453713.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_full['Score'].fillna(0, inplace=True)
# C:\Users\Rafik\AppData\Local\Temp\ipykernel_27632\3763453713.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_hotels = filtered_hotels.groupby('City').apply(lambda x: x.nlargest(20, 'Score')).reset_index(drop=True)

# %%
# Create a new figure for the hotel map
hotel_fig = Figure(width=800, height=400)
hotel_fig.html.add_child(folium.Element("<h3 style='text-align:center;margin-top:20px;'>Top 20 des hotels pour chacune des villes</h3>"))

# Create a map centered around France
hotel_map = folium.Map(location=[46.2276, 2.2137], zoom_start=6, tiles='OpenStreetMap')
hotel_fig.add_child(hotel_map)

# Adds markers for selected hotels
for _, hotel in top_hotels.iterrows():
    folium.Marker(
        location=[hotel['lat_hotels'], hotel['lon_hotels']],
        popup=f"{hotel['Hotel Name']}: Score {hotel['Score']}<br><a href='{hotel['Hotel URL']}' target='_blank'>Book Now</a>",
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(hotel_map)

# Shows the map with hotels
hotel_fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abde251add638dea7fac5eb03dc24e74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 style=&#x27;text-align:center;margin-top:20px;&#x27;&gt;Top 20 des hotels pour chacune des villes&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abde251add638dea7fac5eb03dc24e74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abde251add638dea7fac5eb03dc24e74 = L.map(
#                 &quot;map_abde251add638dea7fac5eb03dc24e74&quot;,
#                 {
#                     center: [46.2276, 2.2137],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc60f15fe795397495899ee4effe502c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc60f15fe795397495899ee4effe502c.addTo(map_abde251add638dea7fac5eb03dc24e74);
#
#
#             var marker_e64b3f733b26630acd2837827443663f = L.marker(
#                 [43.5301204, 5.4489216],
#                 {}
#             ).addTo(map_abde251add638dea7fac5eb03dc24e74);
#
#
#             var icon_7fc225686badd3153f83a4f5e7b44e0e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e64b3f733b26630acd2837827443663f.setIcon(icon_7fc225686badd3153f83a4f5e7b44e0e);
#
#
#         var popup_2edf1646da531f431d083a467b249513 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aede66b8afada29f5e4863ac14f8d3f9 = $(`&lt;div id=&quot;html_aede66b8afada29f5e4863ac14f8d3f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Studio Aix Centre Historique: Score 10.0&lt;br&gt;&lt;a href=&#x27;https://www.booking.com/hotel/fr/charmant-appartement-hypercentre-aix-en-provence.en-gb.html?aid=304142&amp;label=gen173nr-1FCAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYAQm4ARfIAQzYAQHoAQH4AQOIAgGoAgO4Apmz3bIGwAIB0gIkMjhhYmEwYzctZTY1Ny00NzNhLTkyMDAtNDg5MDhlYjcwYWU52AIF4AIB&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=21&amp;hapos=21&amp;sr_order=popularity&amp;srpvid=118e74cce160017d&amp;srepoch=1717000602&amp;from=searchresults#hotelTmpl&#x27; target=&#x27;_blank&#x27;&gt;Book Now&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_2edf1646da531f431d083a467b249513.setContent(html_aede66b8afada29f5e4863ac14f8d3f9);
#
#
#
#         marker_e64b3f733b26630acd2837827443663f.bindPopup(popup_2edf1646da531f431d083a467b249513)
#         ;
#
#
#
#
#             var marker_34de1e3233c82483151a7d794f62b30f = L.marker(
#                 [43.528465619432, 5.452499735058],
#                 {}
#             ).addTo(map_abde251add638dea7fac5eb03dc24e74);
#
#
#             var icon_97fdf7159fdcdb48998e7660877b5ffb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34de1e3233c82483151a7d794f62b30f.setIcon(icon_97fdf7159fdcdb48998e7660877b5ffb);
#
#
#         var popup_b377707f39980c3a6bfb6cefd019f6f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4fcd51d700cecb4461fa5e18d7a99db = $(`&lt;div id=&quot;html_c4fcd51d700cecb4461fa5e18d7a99db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Le Mini - Un voyage en Provence: Score 9.5&lt;br&gt;&lt;a href=&#x27;https://www.booking.com/hotel/fr/studio-terrasse-en-duplex-au-coeur-d-aix-en-provence.en-gb.html?aid=304142&amp;label=gen173nr-1FCAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYAQm4ARfIAQzYAQHoAQH4AQOIAgGoAgO4Apmz3bIGwAIB0gIkMjhhYmEwYzctZTY1Ny00NzNhLTkyMDAtNDg5MDhlYjcwYWU52AIF4AIB&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=15&amp;hapos=15&amp;sr_order=popularity&amp;srpvid=118e74cce160017d&amp;srepoch=1717000602&amp;from=searchresults#hotelTmpl&#x27; target=&#x27;_blank&#x27;&gt;Book Now&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_b377707f39980c3a6bfb6cefd019f6f3.setContent(html_c4fcd51d700cecb4461fa5e18d7a99db);
#
#
#
#         marker_34de1e3233c82483151a7d794f62b30f.bindPopup(popup_b377707f39980c3a6bfb6cefd019f6f3)
#         ;
#
#
#
#
#             var marker_dde31412be899112be20285dfc5fa0e0 = L.marker(
#                 [43.49241698952985, 5.429788827896118],
#                 {}
#             ).addTo(map_abde251add638dea7fac5eb03dc24e74);
#
#
#             var icon_10bbf213b3c8533056486af8cd7c18b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerCo

# %%
# Loads the S3 session and necessary resources # Your AWS access key 
session = boto3.Session(
    aws_access_key_id= # Your AWS access key , 
    aws_secret_access_key=  # Your AWS secret key 
)
s3 = session.resource('s3')

# %%
# Upload the file to S3
s3.Bucket('rafik-001').upload_file('df_full.csv', 'data/df_full.csv')

# %%
# Downloading and reading a CSV file from an S3 bucket
try:
    obj = s3.Object('rafik-001', 'data/df_full.csv')
    df_s3 = pd.read_csv(BytesIO(obj.get()['Body'].read()))
    print("File downloaded successfully")
except Exception as e:
    print(e)
# Out:
# File downloaded successfully

# %%
# Sanity check of df
df_s3.head()
# Out:
#                 City                 Hotel Name  \
# 0  Mont Saint Michel                 Hôtel Vert
# 1  Mont Saint Michel      Les Terrasses Poulard
# 2  Mont Saint Michel  Mercure Mont Saint Michel
# 3  Mont Saint Michel           Le Relais Du Roy
# 4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description  lat_hotels  lon_hotels  \
# 0  Hotel Vert offers pastel-coloured rooms with a...   48.614700   -1.509617
# 1  Composed of 2 different buildings, Les Terrass...   48.635349   -1.510379
# 2  This Mercure is situated in parkland just 2 km...   48.614247   -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...   48.616263   -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...   48.617587   -1.510396
#
#     Latitude  Longitude                                            Weather  \
# 0  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 1  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 2  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 3  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 4  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
#
#    AverageTemp  TotalPrecipitation
# 0     18.61775                8.34
# 1     18.61775                8.34
# 2     18.61775                8.34
# 3     18.61775                8.34
# 4     18.61775                8.34

# %%
df_s3[['City', 'Hotel Name', 'Hotel URL', 'Score', 'Description', 'lat_hotels','lon_hotels', 'Latitude', 'Longitude', 'AverageTemp','TotalPrecipitation']]
# Out:
#                   City                                         Hotel Name  \
# 0    Mont Saint Michel                                         Hôtel Vert
# 1    Mont Saint Michel                              Les Terrasses Poulard
# 2    Mont Saint Michel                          Mercure Mont Saint Michel
# 3    Mont Saint Michel                                   Le Relais Du Roy
# 4    Mont Saint Michel                             Le Relais Saint Michel
# ..                 ...                                                ...
# 871            Bayonne  Studio avec parking à 12mns du centre historiq...
# 872        La Rochelle                         360 degrés sur la rochelle
# 873        La Rochelle   La Belle Amarre-Bed and Breakfast-Maison d'Hôtes
# 874        La Rochelle                                  Hôtel La Fabrique
# 875        La Rochelle  Charmant cocon iodé cosy équipé, baigné de lum...
#
#                                              Hotel URL  Score  \
# 0    https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1    https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2    https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3    https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4    https://www.booking.com/hotel/fr/le-relais-sai...    8.0
# ..                                                 ...    ...
# 871  https://www.booking.com/hotel/fr/a-12mns-du-ce...    NaN
# 872  https://www.booking.com/hotel/fr/360-degres-su...    9.1
# 873  https://www.booking.com/hotel/fr/la-belle-amar...    9.4
# 874  https://www.booking.com/hotel/fr/la-fabrique-l...    8.4
# 875  https://www.booking.com/hotel/fr/charmand-coco...    9.1
#
#                                            Description  lat_hotels  \
# 0    Hotel Vert offers pastel-coloured rooms with a...   48.614700
# 1    Composed of 2 different buildings, Les Terrass...   48.635349
# 2    This Mercure is situated in parkland just 2 km...   48.614247
# 3    Le Relais Du Roy is a 3-star hotel situated ne...   48.616263
# 4    Le Relais Saint Michel is an hotel facing the ...   48.617587
# ..                                                 ...         ...
# 871                          Managed by a private host   43.485403
# 872                          Managed by a private host   46.166189
# 873                          Managed by a private host   46.158662
# 874  Hôtel La Fabrique offers accommodation in La R...   46.156155
# 875  Boasting a bar, the recently renovated Charman...   46.162449
#
#      lon_hotels   Latitude  Longitude  AverageTemp  TotalPrecipitation
# 0     -1.509617  48.635954  -1.511460     18.61775                8.34
# 1     -1.510379  48.635954  -1.511460     18.61775                8.34
# 2     -1.510545  48.635954  -1.511460     18.61775                8.34
# 3     -1.510906  48.635954  -1.511460     18.61775                8.34
# 4     -1.510396  48.635954  -1.511460     18.61775                8.34
# ..          ...        ...        ...          ...                 ...
# 871   -1.487549  43.494514  -1.473666     20.69975                0.62
# 872   -1.146359  46.159113  -1.152043     19.45650                4.64
# 873   -1.155056  46.159113  -1.152043     19.45650                4.64
# 874   -1.148583  46.159113  -1.152043     19.45650                4.64
# 875   -1.148847  46.159113  -1.152043     19.45650                4.64
#
# [876 rows x 11 columns]

# %%
# Identification of the information contained in the weather column for the 1st line 
print(df_s3['Weather'].iloc[0])
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1721001600, 'main': {'temp': 289.08, 'feels_like': 288.79, 'temp_min': 287.26, 'temp_max': 289.08, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 1006, 'humidity': 79, 'temp_kf': 1.82}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 52}, 'wind': {'speed': 2.63, 'deg': 159, 'gust': 2.79}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2024-07-15 00:00:00'}, {'dt': 1721012400, 'main': {'temp': 287.72, 'feels_like': 287.3, 'temp_min': 286.59, 'temp_max': 287.72, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1005, 'humidity': 79, 'temp_kf': 1.13}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 82}, 'wind': {'speed': 2.93, 'deg': 137, 'gust': 3.81}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2024-07-15 03:00:00'}, {'dt': 1721023200, 'main': {'temp': 289.04, 'feels_like': 288.8, 'temp_min': 289.04, 'temp_max': 289.04, 'pressure': 1008, 'sea_level': 1008, 'grnd_level': 1003, 'humidity': 81, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.82, 'deg': 132, 'gust': 9.44}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-07-15 06:00:00'}, {'dt': 1721034000, 'main': {'temp': 287.69, 'feels_like': 287.71, 'temp_min': 287.69, 'temp_max': 287.69, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 1003, 'humidity': 96, 'temp_kf': 0}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'clouds': {'all': 100}, 'wind': {'speed': 1.11, 'deg': 114, 'gust': 1.68}, 'visibility': 6175, 'pop': 1, 'rain': {'3h': 4.01}, 'sys': {'pod': 'd'}, 'dt_txt': '2024-07-15 09:00:00'}, {'dt': 1721044800, 'main': {'temp': 291.34, 'feels_like': 291.54, 'temp_min': 291.34, 'temp_max': 291.34, 'pressure': 1008, 'sea_level': 1008, 'grnd_level': 1003, 'humidity': 89, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 100}, 'wind': {'speed': 5.32, 'deg': 190, 'gust': 10.28}, 'visibility': 10000, 'pop': 1, 'rain': {'3h': 1.26}, 'sys': {'pod': 'd'}, 'dt_txt': '2024-07-15 12:00:00'}, {'dt': 1721055600, 'main': {'temp': 295.09, 'feels_like': 295.06, 'temp_min': 295.09, 'temp_max': 295.09, 'pressure': 1007, 'sea_level': 1007, 'grnd_level': 1002, 'humidity': 66, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 71}, 'wind': {'speed': 6.56, 'deg': 211, 'gust': 9.56}, 'visibility': 10000, 'pop': 1, 'rain': {'3h': 0.74}, 'sys': {'pod': 'd'}, 'dt_txt': '2024-07-15 15:00:00'}, {'dt': 1721066400, 'main': {'temp': 291.18, 'feels_like': 291.23, 'temp_min': 291.18, 'temp_max': 291.18, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 1004, 'humidity': 84, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 57}, 'wind': {'speed': 5.01, 'deg': 273, 'gust': 8.48}, 'visibility': 10000, 'pop': 1, 'rain': {'3h': 1.47}, 'sys': {'pod': 'd'}, 'dt_txt': '2024-07-15 18:00:00'}, {'dt': 1721077200, 'main': {'temp': 288.64, 'feels_like': 288.65, 'temp_min': 288.64, 'temp_max': 288.64, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 1005, 'humidity': 92, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 26}, 'wind': {'speed': 6.2, 'deg': 211, 'gust': 11.5}, 'visibility': 10000, 'pop': 1, 'rain': {'3h': 0.55}, 'sys': {'pod': 'n'}, 'dt_txt': '2024-07-15 21:00:00'}, {'dt': 1721088000, 'main': {'temp': 287.51, 'feels_like': 287.48, 'temp_min': 287.51, 'temp_max': 287.51, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 1006, 'humidity': 95, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'a ...

# %%
# Function to extract data from weather column
def extract_combined_weather_features(row):
    try:
        # Attempts to convert weather string to JSON, otherwise converts to dictionary
        if isinstance(row['Weather'], str) and row['Weather'].strip().startswith('{'):
            try:
                weather_data = json.loads(row['Weather'])
            except json.JSONDecodeError:
                weather_data = ast.literal_eval(row['Weather'].replace("'", '"'))
        else:
            weather_data = ast.literal_eval(row['Weather'])
        
        if 'daily' in weather_data:
            daily_data = weather_data['daily'] # Access daily data
        
            # Calculations for weather measurements to extract
            max_temp = max(day['temp']['max'] for day in daily_data)
            min_temp = min(day['temp']['min'] for day in daily_data)
            avg_temp = sum(day['temp']['day'] for day in daily_data) / len(daily_data)
            avg_humidity = sum(day['humidity'] for day in daily_data) / len(daily_data)
            weather_descriptions = ', '.join(set(day['weather'][0]['description'] for day in daily_data))
            avg_wind_speed = sum(day['wind_speed'] for day in daily_data) / len(daily_data)
            max_uv = max(day['uvi'] for day in daily_data)
            total_precip = sum(day.get('rain', 0) for day in daily_data)
            avg_pressure = sum(day['pressure'] for day in daily_data) / len(daily_data)
            
            # Returns all calculated measurements as a series
            return pd.Series([max_temp, min_temp, avg_temp, avg_humidity, weather_descriptions, avg_wind_speed, max_uv, total_precip, avg_pressure])
        else:
            # If 'daily' key doesn't exist, return None for all attributes
            return pd.Series([None] * 9)
    except Exception as e:
        print(f"Error processing row: {e}")
        return pd.Series([None] * 9) # Return None for each attribute on error

# Assuming df_s3 is your DataFrame
# Applying the function on df_s3 to enrich the data
df_s3[['MaxTemp', 'MinTemp', 'AvgTemp', 'AvgHumidity', 'WeatherDesc', 'AvgWindSpeed', 'MaxUV', 'TotalPrecip', 'AvgPressure']] = df_s3.apply(extract_combined_weather_features, axis=1)

# %%
# Show the first rows to check for new data
df_s3.head()
# Out:
#                 City                 Hotel Name  \
# 0  Mont Saint Michel                 Hôtel Vert
# 1  Mont Saint Michel      Les Terrasses Poulard
# 2  Mont Saint Michel  Mercure Mont Saint Michel
# 3  Mont Saint Michel           Le Relais Du Roy
# 4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description  lat_hotels  lon_hotels  \
# 0  Hotel Vert offers pastel-coloured rooms with a...   48.614700   -1.509617
# 1  Composed of 2 different buildings, Les Terrass...   48.635349   -1.510379
# 2  This Mercure is situated in parkland just 2 km...   48.614247   -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...   48.616263   -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...   48.617587   -1.510396
#
#     Latitude  Longitude                                            Weather  \
# 0  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 1  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 2  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 3  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
# 4  48.635954   -1.51146  {'cod': '200', 'message': 0, 'cnt': 40, 'list'...
#
#    ...  TotalPrecipitation  MaxTemp MinTemp AvgTemp AvgHumidity WeatherDesc  \
# 0  ...                8.34     None    None    None        None        None
# 1  ...                8.34     None    None    None        None        None
# 2  ...                8.34     None    None    None        None        None
# 3  ...                8.34     None    None    None        None        None
# 4  ...                8.34     None    None    None        None        None
#
#   AvgWindSpeed MaxUV TotalPrecip AvgPressure
# 0         None  None        None        None
# 1         None  None        None        None
# 2         None  None        None        None
# 3         None  None        None        None
# 4         None  None        None        None
#
# [5 rows x 21 columns]

# %%
# creation of the final dataframe df_final_s3
df_final_s3= df_s3

# %%
# saving final s3 data to a csv file
df_full.to_csv('df_final_s3.csv', index=False)

# %%
# crée un moteur de base de données SQLite en mémoire
engine = create_engine('sqlite:///:memory:', echo=True)

# %%
df_final_s3.to_sql("hotels", engine)
# Out:
# 2024-07-15 00:14:03,286 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-15 00:14:03,289 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("hotels")
# 2024-07-15 00:14:03,289 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-15 00:14:03,290 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("hotels")
# 2024-07-15 00:14:03,290 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-15 00:14:03,292 INFO sqlalchemy.engine.Engine
# CREATE TABLE hotels (
# 	"index" BIGINT,
# 	"City" TEXT,
# 	"Hotel Name" TEXT,
# 	"Hotel URL" TEXT,
# 	"Score" FLOAT,
# 	"Description" TEXT,
# 	lat_hotels FLOAT,
# 	lon_hotels FLOAT,
# 	"Latitude" FLOAT,
# 	"Longitude" FLOAT,
# 	"Weather" TEXT,
# 	"AverageTemp" FLOAT,
# 	"TotalPrecipitation" FLOAT,
# 	"MaxTemp" TEXT,
# 	"MinTemp" TEXT,
# 	"AvgTemp" TEXT,
# 	"AvgHumidity" TEXT,
# 	"WeatherDesc" TEXT,
# 	"AvgWindSpeed" TEXT,
# 	"MaxUV" TEXT,
# 	"TotalPrecip" TEXT,
# 	"AvgPressure" TEXT
# )
#
#
# 2024-07-15 00:14:03,292 INFO sqlalchemy.engine.Engine [no key 0.00033s] ()
# 2024-07-15 00:14:03,292 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hotels_index ON hotels ("index")
# 2024-07-15 00:14:03,292 INFO sqlalchemy.engine.Engine [no key 0.00029s] ()
# 2024-07-15 00:14:03,302 INFO sqlalchemy.engine.Engine INSERT INTO hotels ("index", "City", "Hotel Name", "Hotel URL", "Score", "Description", lat_hotels, lon_hotels, "Latitude", "Longitude", "Weather", "AverageTemp", "TotalPrecipitation", "MaxTemp", "MinTemp", "AvgTemp", "AvgHumidity", "WeatherDesc", "AvgWindSpeed", "MaxUV", "TotalPrecip", "AvgPressure") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2024-07-15 00:14:03,302 INFO sqlalchemy.engine.Engine [generated in 0.00537s] [(0, 'Mont Saint Michel', 'Hôtel Vert', 'https://www.booking.com/hotel/fr/vert.en-gb.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgzWARoTYgBAZgBCbgBF8gBDNgBAegB ... (163 characters truncated) ... _children=0&hpos=1&hapos=1&sr_order=popularity&srpvid=ec0d731635cc027e&srepoch=1716999726&from_sustainable_property_sr=1&from=searchresults#hotelTmpl', 8.0, 'Hotel Vert offers pastel-coloured rooms with a private bathroom, TV and free Wi-Fi access. It is located 2 km from the Mont Saint-Michel tidal island on the Normandy Coast. ', 48.61470048629041, -1.5096169710159302, 48.6359541, -1.511459954959514, "{'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1721001600, 'main': {'temp': 289.08, 'feels_like': 288.79, 'temp_min': 287.26, 'temp_max': 28 ... (17856 characters truncated) ... sur-Mer', 'coord': {'lat': 48.636, 'lon': -1.5115}, 'country': 'FR', 'population': 0, 'timezone': 7200, 'sunrise': 1721017184, 'sunset': 1721073836}}", 18.61775000000002, 8.34, None, None, None, None, None, None, None, None, None), (1, 'Mont Saint Michel', 'Les Terrasses Poulard', 'https://www.booking.com/hotel/fr/les-terrasses-poulard.en-gb.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgzWARoTYgBAZg ... (149 characters truncated) ... no_rooms=1&group_children=0&req_children=0&hpos=2&hapos=2&sr_order=popularity&srpvid=ec0d731635cc027e&srepoch=1716999726&from=searchresults#hotelTmpl', 7.4, 'Composed of 2 different buildings, Les Terrasses Poulard is a historical property in the heart of Mont Saint-Michel and offers views of the bay, the village and the street. ', 48.63534942564122, -1.5103787183761597, 48.6359541, -1.511459954959514, "{'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1721001600, 'main': {'temp': 289.08, 'feels_like': 288.79, 'temp_min': 287.26, 'temp_max': 28 ... (17856 characters truncated) ... sur-Mer', 'coord': {'lat': 48.636, 'lon': -1.5115}, 'country': 'FR', 'population': 0, 'timezone': 7200, 'sunrise': 1721017184, 'sunset': 1721073836}}", 18.61775000000002, 8.34, None, None, None, None, None, None, None, None, None), (2, 'Mont Saint Michel', 'Mercure Mont Saint Michel', 'https://www.booking.com/hotel/fr/mont-saint-michel.en-gb.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgzWARoTYgBAZgBCbg ... (176 characters truncated) ... _children=0&hpos=3&hapos=3&sr_order=popularity&srpvid=ec0d731635cc027e&srepoch=1716999726&from_sustainable_property_sr=1&from=searchresults#hotelTmpl', 8.2, 'This Mercure is situated in parkland just 2 km from the abbey of Mont Saint Michel. It offers spacious en suite rooms, a restaurant and bar and plenty of free on-site parking. ', 48.61424652959294, -1.510545015335083, 48.6359541, -1.511459954959514, "{'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1721001600, 'main': {'temp': 289.08, 'feels_like': 288.79, 'temp_min': 287.26, 'temp_max': 28 ... (17856 characters truncated) ... sur-Mer', 'coord': {'lat': 48.636, 'lon': -1.5115}, 'country': 'FR', 'population': 0, 'timezone': 7200, 'sunrise': 1721017184, 'sunset': 1721073836}}", 18.61775000000002, 8.34, None, None, None, None, None, None, None, None, None), (3, 'Mont Saint Michel', 'Le Relais Du Roy', 'https://www.booking.com/hotel/fr/le-relais-du-roy.en-gb.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgzWARoTYgBAZgBCbgB ... (175 characters truncated) ... _children=0&hpos=4&hapos=4&sr_order=popularity&srpvid=ec0d731635cc027e&srepoch=1716999726&from_sustainable_property_sr=1&from=searchresults#hotelTmpl', 8.1, 'Le Relais Du Roy is a 3-star hotel situated next to the River Couesnon, just 1.5 km from the Mont Saint-Michel and 50 metres from the free shuttle bus. ', 48.61626270451236, -1.510905772447586, 48.6359541, -1.511459954959514, "{'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1721001600, 'main': {'temp': 289.08, 'feels_like': 288.79, 'temp_min ...
# 2024-07-15 00:14:03,316 INFO sqlalchemy.engine.Engine COMMIT
# 876

# %%
# Connexion à la base
conn = engine.connect()

# %%
data = text("SELECT * FROM hotels")

# %%
# récupérer les résultats sous forme de DataFrame.
pd.read_sql_query(data, conn).head()
# Out:
# 2024-07-15 00:14:46,946 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-15 00:14:46,947 INFO sqlalchemy.engine.Engine SELECT * FROM hotels
# 2024-07-15 00:14:46,947 INFO sqlalchemy.engine.Engine [generated in 0.00080s] ()
#    index               City                 Hotel Name  \
# 0      0  Mont Saint Michel                 Hôtel Vert
# 1      1  Mont Saint Michel      Les Terrasses Poulard
# 2      2  Mont Saint Michel  Mercure Mont Saint Michel
# 3      3  Mont Saint Michel           Le Relais Du Roy
# 4      4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description  lat_hotels  lon_hotels  \
# 0  Hotel Vert offers pastel-coloured rooms with a...   48.614700   -1.509617
# 1  Composed of 2 different buildings, Les Terrass...   48.635349   -1.510379
# 2  This Mercure is situated in parkland just 2 km...   48.614247   -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...   48.616263   -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...   48.617587   -1.510396
#
#     Latitude  Longitude  ... TotalPrecipitation  MaxTemp  MinTemp AvgTemp  \
# 0  48.635954   -1.51146  ...               8.34     None     None    None
# 1  48.635954   -1.51146  ...               8.34     None     None    None
# 2  48.635954   -1.51146  ...               8.34     None     None    None
# 3  48.635954   -1.51146  ...               8.34     None     None    None
# 4  48.635954   -1.51146  ...               8.34     None     None    None
#
#   AvgHumidity WeatherDesc AvgWindSpeed MaxUV TotalPrecip AvgPressure
# 0        None        None         None  None        None        None
# 1        None        None         None  None        None        None
# 2        None        None         None  None        None        None
# 3        None        None         None  None        None        None
# 4        None        None         None  None        None        None
#
# [5 rows x 22 columns]
